# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sna
# %matplot inline

# %%
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv(r"C:\Users\NAjani\Jupyter\GDP_Netherlands.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    63 non-null     int64
#  1   GDP     63 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
#Visualize
print(data.iloc[-1]['Year'])
# Out:
# 2022.0

# %%
sna.regplot(x='Year', y = 'GDP', data = data)
# Out:
# <Axes: xlabel='Year', ylabel='GDP'>

# %%
# regression

# 1. create instance

Iri = LinearRegression()

# %%
#2. Train model

Iri.fit(data[['Year']].values, data.GDP)
# Out:
# LinearRegression()

# %%
Iri.predict([[2023]])
# Out:
# array([57557.28357888])
